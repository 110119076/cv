# %%
import numpy as np

# %%
import urllib.request

# %%
url="https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
raw=urllib.request.urlopen(url)
ds=np.loadtxt(raw,delimiter=',')

# %%
ds
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 459ms/step - loss: 109.4298
# Epoch 2/500
# 1/1 [==============================] - 0s 5ms/step - loss: 86.1076
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 67.7585
# Epoch 4/500
# 1/1 [==============================] - 0s 5ms/step - loss: 53.3220
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 41.9639
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 33.0276
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 25.9967
# Epoch 8/500
# 1/1 [==============================] - 0s 5ms/step - loss: 20.4648
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 16.1124
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 12.6879
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 9.9934
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 7.8733
# Epoch 13/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.2051
# Epoch 14/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.8924
# Epoch 15/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.8594
# Epoch 16/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.0465
# Epoch 17/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4067
# Epoch 18/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9031
# Epoch 19/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.5068
# Epoch 20/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1947
# Epoch 21/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9491
# Epoch 22/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7556
# Epoch 23/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6032
# Epoch 24/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4831
# Epoch 25/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3884
# Epoch 26/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3138
# Epoch 27/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2549
# Epoch 28/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2084
# Epoch 29/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1717
# Epoch 30/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1426
# Epoch 31/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1196
# Epoch 32/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1013
# Epoch 33/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0868
# Epoch 34/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0752
# Epoch 35/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0660
# Epoch 36/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0586
# Epoch 37/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0526
# Epoch 38/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0478
# Epoch 39/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0439
# Epoch 40/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0406
# Epoch 41/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0380
# Epoch 42/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0358
# Epoch 43/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0339
# Epoch 44/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0323
# Epoch 45/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0309
# Epoch 46/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0298
# Epoch 47/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0287
# Epoch 48/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0278
# Epoch 49/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0269
# Epoch 50/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0262
# Epoch 51/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0255
# Epoch 52/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0248
# Epoch 53/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0242
# Epoch 54/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0236
# Epoch 55/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0231
# Epoch 56/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0226
# Epoch 57/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0221
# Epoch 58/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0216
# Epoch 59/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0211
# Epoch 60/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0207
# Epoch 61/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0202
# Epoch 62/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0198
# Epoch 63/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0194
# Epoch 64/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0190
# Epoch 65/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0186
# Epoch 66/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0182
# Epoch 67/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0178
# Epoch 68/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0174
# Epoch 69/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0171
# Epoch 70/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0167
# Epoch 71/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0164
# Epoch 72/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0160
# Epoch 73/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0157
# Epoch 74/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0154
# Epoch 75/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0151
# Epoch 76/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0148
# Epoch 77/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0145
# Epoch 78/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0142
# Epoch 79/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0139
# Epoch 80/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0136
# Epoch 81/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0133
# Epoch 82/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0130
# Epoch 83/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0128
# Epoch 84/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0125
# Epoch 85/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0122
# Epoch 86/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0120
# Epoch 87/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0117
# Epoch 88/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0115
# Epoch 89/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0113
# Epoch 90/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0110
# Epoch 91/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0108
# Epoch 92/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0106
# Epoch 93/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0104
# Epoch 94/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0102
# Epoch 95/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0100
# Epoch 96/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0097
# Epoch 97/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0095
# Epoch 98/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0093
# Epoch 99/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0092
# Epoch 100/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0090
# Epoch 101/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0088
# Epoch 102/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0086
# Epoch 103/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0084
# Epoch 104/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0083
# Epoch 105/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0081
# Epoch 106/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0079
# Epoch 107/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0078
# Epoch 108/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0076
# Epoch 109/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0074
# Epoch 110/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 111/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0071
# Epoch 112/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0070
# Epoch 113/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0068
# Epoch 114/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0067
# Epoch 115/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 116/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0064
# Epoch 117/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0063
# Epoch 118/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0062
# Epoch 119/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0060
# Epoch 120/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0059
# Epoch 121/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0058
# Epoch 122/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0057
# Epoch 123/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0056
# Epoch 124/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0055
# Epoch 125/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0053
# Epoch 126/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0052
# Epoch 127/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0051
# Epoch 128/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0050
# Epoch 129/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0049
# Epoch 130/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0048
# Epoch 131/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0047
# Epoch 132/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 133/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0045
# Epoch 134/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0044
# Epoch 135/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 136/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0042
# Epoch 137/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 138/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 139/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 140/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 141/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0038
# Epoch 142/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0038
# Epoch 143/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 144/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0036
# Epoch 145/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0035
# Epoch 146/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0035
# Epoch 147/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0034
# Epoch 148/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033
# Epoch 149/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 150/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 151/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 152/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0030
# Epoch 153/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0030
# Epoch 154/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 155/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 156/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0028
# Epoch 157/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 158/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0027
# Epoch 159/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0026
# Epoch 160/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 161/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0025
# Epoch 162/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 163/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 164/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 165/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 166/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 167/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 168/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 169/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 170/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 171/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 172/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 173/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0020
# Epoch 174/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0019
# Epoch 175/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 176/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 177/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 178/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 179/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0017
# Epoch 180/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 181/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0017
# Epoch 182/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 183/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 184/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 185/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 186/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 187/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 188/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 189/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 190/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0014
# Epoch 191/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 192/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 193/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 194/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 195/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 196/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 197/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 198/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 199/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 200/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 201/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 202/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 203/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 204/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 205/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 206/500
# 1/1 [==============================] - 0s 5ms/step - loss: 9.9384e-04
# Epoch 207/500
# 1/1 [==============================] - 0s 4ms/step - loss: 9.7344e-04
# Epoch 208/500
# 1/1 [==============================] - 0s 3ms/step - loss: 9.5344e-04
# Epoch 209/500
# 1/1 [==============================] - 0s 5ms/step - loss: 9.3386e-04
# Epoch 210/500
# 1/1 [==============================] - 0s 8ms/step - loss: 9.1468e-04
# Epoch 211/500
# 1/1 [==============================] - 0s 7ms/step - loss: 8.9589e-04
# Epoch 212/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.7749e-04
# Epoch 213/500
# 1/1 [==============================] - 0s 3ms/step - loss: 8.5946e-04
# Epoch 214/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.4181e-04
# Epoch 215/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.2452e-04
# Epoch 216/500
# 1/1 [==============================] - 0s 5ms/step - loss: 8.0758e-04
# Epoch 217/500
# 1/1 [==============================] - 0s 5ms/step - loss: 7.9099e-04
# Epoch 218/500
# 1/1 [==============================] - 0s 3ms/step - loss: 7.7475e-04
# Epoch 219/500
# 1/1 [==============================] - 0s 4ms/step - loss: 7.5884e-04
# Epoch 220/500
# 1/1 [==============================] - 0s 4ms/step - loss: 7.4325e-04
# Epoch 221/500
# 1/1 [==============================] - 0s 6ms/step - loss: 7.2799e-04
# Epoch 222/500
# 1/1 [==============================] - 0s 4ms/step - loss: 7.1304e-04
# Epoch 223/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.9839e-04
# Epoch 224/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.8404e-04
# Epoch 225/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.6999e-04
# Epoch 226/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.5623e-04
# Epoch 227/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.4275e-04
# Epoch 228/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.2955e-04
# Epoch 229/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.1662e-04
# Epoch 230/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.0395e-04
# Epoch 231/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.9155e-04
# Epoch 232/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.7940e-04
# Epoch 233/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.6750e-04
# Epoch 234/500
# 1/1 [==============================] - 0s 5ms/step - loss: 5.5584e-04
# Epoch 235/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.4442e-04
# Epoch 236/500
# 1/1 [==============================] - 0s 5ms/step - loss: 5.3324e-04
# Epoch 237/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.2229e-04
# Epoch 238/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.1156e-04
# Epoch 239/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.0105e-04
# Epoch 240/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9076e-04
# Epoch 241/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.8068e-04
# Epoch 242/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.7080e-04
# Epoch 243/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.6114e-04
# Epoch 244/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.5166e-04
# Epoch 245/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.4239e-04
# Epoch 246/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.3330e-04
# Epoch 247/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2440e-04
# Epoch 248/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.1568e-04
# Epoch 249/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.0715e-04
# Epoch 250/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.9878e-04
# Epoch 251/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.9059e-04
# Epoch 252/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8256e-04
# Epoch 253/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.7470e-04
# Epoch 254/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.6701e-04
# Epoch 255/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.5947e-04
# Epoch 256/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.5208e-04
# Epoch 257/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.4485e-04
# Epoch 258/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3777e-04
# Epoch 259/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3083e-04
# Epoch 260/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.2403e-04
# Epoch 261/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.1738e-04
# Epoch 262/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.1086e-04
# Epoch 263/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0447e-04
# Epoch 264/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9822e-04
# Epoch 265/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.9209e-04
# Epoch 266/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8609e-04
# Epoch 267/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8021e-04
# Epoch 268/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.7446e-04
# Epoch 269/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6882e-04
# Epoch 270/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.6330e-04
# Epoch 271/500
# 1/1 [==============================] - 0s 16ms/step - loss: 2.5789e-04
# Epoch 272/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5260e-04
# Epoch 273/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4741e-04
# Epoch 274/500
# 1/1 [==============================] - 0s 14ms/step - loss: 2.4233e-04
# Epoch 275/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3735e-04
# Epoch 276/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.3247e-04
# Epoch 277/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.2770e-04
# Epoch 278/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.2302e-04
# Epoch 279/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.1845e-04
# Epoch 280/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1396e-04
# Epoch 281/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.0956e-04
# Epoch 282/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.0526e-04
# Epoch 283/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.0104e-04
# Epoch 284/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9691e-04
# Epoch 285/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9286e-04
# Epoch 286/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.8890e-04
# Epoch 287/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8502e-04
# Epoch 288/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8122e-04
# Epoch 289/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7750e-04
# Epoch 290/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7385e-04
# Epoch 291/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7028e-04
# Epoch 292/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6678e-04
# Epoch 293/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6336e-04
# Epoch 294/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6001e-04
# Epoch 295/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5672e-04
# Epoch 296/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.5350e-04
# Epoch 297/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5035e-04
# Epoch 298/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4726e-04
# Epoch 299/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4423e-04
# Epoch 300/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4127e-04
# Epoch 301/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3837e-04
# Epoch 302/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3553e-04
# Epoch 303/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3274e-04
# Epoch 304/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3002e-04
# Epoch 305/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2735e-04
# Epoch 306/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2473e-04
# Epoch 307/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2217e-04
# Epoch 308/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1966e-04
# Epoch 309/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1720e-04
# Epoch 310/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1479e-04
# Epoch 311/500
# 1/1 [==============================] - 0s 22ms/step - loss: 1.1244e-04
# Epoch 312/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1013e-04
# Epoch 313/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0787e-04
# Epoch 314/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0565e-04
# Epoch 315/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0348e-04
# Epoch 316/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0136e-04
# Epoch 317/500
# 1/1 [==============================] - 0s 5ms/step - loss: 9.9274e-05
# Epoch 318/500
# 1/1 [==============================] - 0s 4ms/step - loss: 9.7234e-05
# Epoch 319/500
# 1/1 [==============================] - 0s 16ms/step - loss: 9.5237e-05
# Epoch 320/500
# 1/1 [==============================] - 0s 3ms/step - loss: 9.3281e-05
# Epoch 321/500
# 1/1 [==============================] - 0s 7ms/step - loss: 9.1365e-05
# Epoch 322/500
# 1/1 [==============================] - 0s 3ms/step - loss: 8.9488e-05
# Epoch 323/500
# 1/1 [==============================] - 0s 3ms/step - loss: 8.7651e-05
# Epoch 324/500
# 1/1 [==============================] - 0s 5ms/step - loss: 8.5851e-05
# Epoch 325/500
# 1/1 [==============================] - 0s 3ms/step - loss: 8.4087e-05
# Epoch 326/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.2359e-05
# Epoch 327/500
# 1/1 [==============================] - 0s 3ms/step - loss: 8.0668e-05
# Epoch 328/500
# 1/1 [==============================] - 0s 4ms/step - loss: 7.9011e-05
# Epoch 329/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.7389e-05
# Epoch 330/500
# 1/1 [==============================] - 0s 3ms/step - loss: 7.5800e-05
# Epoch 331/500
# 1/1 [==============================] - 0s 4ms/step - loss: 7.4242e-05
# Epoch 332/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.2717e-05
# Epoch 333/500
# 1/1 [==============================] - 0s 4ms/step - loss: 7.1224e-05
# Epoch 334/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.9760e-05
# Epoch 335/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.8328e-05
# Epoch 336/500
# 1/1 [==============================] - 0s 5ms/step - loss: 6.6926e-05
# Epoch 337/500
# 1/1 [==============================] - 0s 5ms/step - loss: 6.5552e-05
# Epoch 338/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.4205e-05
# Epoch 339/500
# 1/1 [==============================] - 0s 14ms/step - loss: 6.2886e-05
# Epoch 340/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.1595e-05
# Epoch 341/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.0330e-05
# Epoch 342/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.9091e-05
# Epoch 343/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.7876e-05
# Epoch 344/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.6687e-05
# Epoch 345/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.5522e-05
# Epoch 346/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.4381e-05
# Epoch 347/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3266e-05
# Epoch 348/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.2171e-05
# Epoch 349/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.1099e-05
# Epoch 350/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0049e-05
# Epoch 351/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.9020e-05
# Epoch 352/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.8013e-05
# Epoch 353/500
# 1/1 [==============================] - 0s 10ms/step - loss: 4.7028e-05
# Epoch 354/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.6061e-05
# Epoch 355/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.5114e-05
# Epoch 356/500
# 1/1 [==============================] - 0s 10ms/step - loss: 4.4188e-05
# Epoch 357/500
# 1/1 [==============================] - 0s 24ms/step - loss: 4.3279e-05
# Epoch 358/500
# 1/1 [==============================] - 0s 17ms/step - loss: 4.2389e-05
# Epoch 359/500
# 1/1 [==============================] - 0s 15ms/step - loss: 4.1519e-05
# Epoch 360/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.0666e-05
# Epoch 361/500
# 1/1 [==============================] - 0s 15ms/step - loss: 3.9831e-05
# Epoch 362/500
# 1/1 [==============================] - 0s 11ms/step - loss: 3.9012e-05
# Epoch 363/500
# 1/1 [==============================] - 0s 13ms/step - loss: 3.8212e-05
# Epoch 364/500
# 1/1 [==============================] - 0s 18ms/step - loss: 3.7426e-05
# Epoch 365/500
# 1/1 [==============================] - 0s 11ms/step - loss: 3.6658e-05
# Epoch 366/500
# 1/1 [==============================] - 0s 11ms/step - loss: 3.5904e-05
# Epoch 367/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.5167e-05
# Epoch 368/500
# 1/1 [==============================] - 0s 5ms/step - loss: 3.4445e-05
# Epoch 369/500
# 1/1 [==============================] - 0s 14ms/step - loss: 3.3738e-05
# Epoch 370/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3045e-05
# Epoch 371/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.2368e-05
# Epoch 372/500
# 1/1 [==============================] - 0s 17ms/step - loss: 3.1702e-05
# Epoch 373/500
# 1/1 [==============================] - 0s 13ms/step - loss: 3.1051e-05
# Epoch 374/500
# 1/1 [==============================] - 0s 15ms/step - loss: 3.0413e-05
# Epoch 375/500
# 1/1 [==============================] - 0s 13ms/step - loss: 2.9788e-05
# Epoch 376/500
# 1/1 [==============================] - 0s 11ms/step - loss: 2.9176e-05
# Epoch 377/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.8577e-05
# Epoch 378/500
# 1/1 [==============================] - 0s 10ms/step - loss: 2.7990e-05
# Epoch 379/500
# 1/1 [==============================] - 0s 10ms/step - loss: 2.7415e-05
# Epoch 380/500
# 1/1 [==============================] - 0s 12ms/step - loss: 2.6851e-05
# Epoch 381/500
# 1/1 [==============================] - 0s 11ms/step - loss: 2.6300e-05
# Epoch 382/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5760e-05
# Epoch 383/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.5231e-05
# Epoch 384/500
# 1/1 [==============================] - 0s 10ms/step - loss: 2.4713e-05
# Epoch 385/500
# 1/1 [==============================] - 0s 11ms/step - loss: 2.4206e-05
# Epoch 386/500
# 1/1 [==============================] - 0s 14ms/step - loss: 2.3709e-05
# Epoch 387/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3221e-05
# Epoch 388/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.2745e-05
# Epoch 389/500
# 1/1 [==============================] - 0s 12ms/step - loss: 2.2277e-05
# Epoch 390/500
# 1/1 [==============================] - 0s 10ms/step - loss: 2.1821e-05
# Epoch 391/500
# 1/1 [==============================] - 0s 10ms/step - loss: 2.1372e-05
# Epoch 392/500
# 1/1 [==============================] - 0s 17ms/step - loss: 2.0933e-05
# Epoch 393/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.0502e-05
# Epoch 394/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.0081e-05
# Epoch 395/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9669e-05
# Epoch 396/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9265e-05
# Epoch 397/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.8869e-05
# Epoch 398/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8482e-05
# Epoch 399/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8103e-05
# Epoch 400/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7731e-05
# Epoch 401/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7367e-05
# Epoch 402/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7010e-05
# Epoch 403/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6661e-05
# Epoch 404/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6319e-05
# Epoch 405/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.5984e-05
# Epoch 406/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.5655e-05
# Epoch 407/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5334e-05
# Epoch 408/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.5019e-05
# Epoch 409/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4710e-05
# Epoch 410/500
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4408e-05
# Epoch 411/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.4112e-05
# Epoch 412/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3822e-05
# Epoch 413/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3539e-05
# Epoch 414/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3261e-05
# Epoch 415/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2988e-05
# Epoch 416/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2721e-05
# Epoch 417/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2460e-05
# Epoch 418/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2204e-05
# Epoch 419/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1954e-05
# Epoch 420/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1708e-05
# Epoch 421/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1467e-05
# Epoch 422/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1232e-05
# Epoch 423/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1001e-05
# Epoch 424/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0776e-05
# Epoch 425/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0554e-05
# Epoch 426/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0337e-05
# Epoch 427/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0124e-05
# Epoch 428/500
# 1/1 [==============================] - 0s 3ms/step - loss: 9.9167e-06
# Epoch 429/500
# 1/1 [==============================] - 0s 4ms/step - loss: 9.7133e-06
# Epoch 430/500
# 1/1 [==============================] - 0s 10ms/step - loss: 9.5134e-06
# Epoch 431/500
# 1/1 [==============================] - 0s 8ms/step - loss: 9.3178e-06
# Epoch 432/500
# 1/1 [==============================] - 0s 19ms/step - loss: 9.1268e-06
# Epoch 433/500
# 1/1 [==============================] - 0s 13ms/step - loss: 8.9390e-06
# Epoch 434/500
# 1/1 [==============================] - 0s 15ms/step - loss: 8.7551e-06
# Epoch 435/500
# 1/1 [==============================] - 0s 13ms/step - loss: 8.5754e-06
# Epoch 436/500
# 1/1 [==============================] - 0s 10ms/step - loss: 8.3992e-06
# Epoch 437/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.2270e-06
# Epoch 438/500
# 1/1 [==============================] - 0s 12ms/step - loss: 8.0579e-06
# Epoch 439/500
# 1/1 [==============================] - 0s 5ms/step - loss: 7.8928e-06
# Epoch 440/500
# 1/1 [==============================] - 0s 5ms/step - loss: 7.7304e-06
# Epoch 441/500
# 1/1 [==============================] - 0s 5ms/step - loss: 7.5718e-06
# Epoch 442/500
# 1/1 [==============================] - 0s 4ms/step - loss: 7.4162e-06
# Epoch 443/500
# 1/1 [==============================] - 0s 4ms/step - loss: 7.2641e-06
# Epoch 444/500
# 1/1 [==============================] - 0s 4ms/step - loss: 7.1152e-06
# Epoch 445/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.9692e-06
# Epoch 446/500
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8256e-06
# Epoch 447/500
# 1/1 [==============================] - 0s 11ms/step - loss: 6.6855e-06
# Epoch 448/500
# 1/1 [==============================] - 0s 12ms/step - loss: 6.5481e-06
# Epoch 449/500
# 1/1 [==============================] - 0s 10ms/step - loss: 6.4135e-06
# Epoch 450/500
# 1/1 [==============================] - 0s 9ms/step - loss: 6.2822e-06
# Epoch 451/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.1531e-06
# Epoch 452/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.0267e-06
# Epoch 453/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.9027e-06
# Epoch 454/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.7813e-06
# Epoch 455/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.6626e-06
# Epoch 456/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.5462e-06
# Epoch 457/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.4322e-06
# Epoch 458/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.3208e-06
# Epoch 459/500
# 1/1 [==============================] - 0s 11ms/step - loss: 5.2112e-06
# Epoch 460/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.1043e-06
# Epoch 461/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.9993e-06
# Epoch 462/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.8964e-06
# Epoch 463/500
# 1/1 [==============================] - 0s 8ms/step - loss: 4.7959e-06
# Epoch 464/500
# 1/1 [==============================] - 0s 8ms/step - loss: 4.6976e-06
# Epoch 465/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.6010e-06
# Epoch 466/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.5061e-06
# Epoch 467/500
# 1/1 [==============================] - 0s 21ms/step - loss: 4.4137e-06
# Epoch 468/500
# 1/1 [==============================] - 0s 10ms/step - loss: 4.3229e-06
# Epoch 469/500
# 1/1 [==============================] - 0s 11ms/step - loss: 4.2340e-06
# Epoch 470/500
# 1/1 [==============================] - 0s 17ms/step - loss: 4.1469e-06
# Epoch 471/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.0619e-06
# Epoch 472/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.9785e-06
# Epoch 473/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.8967e-06
# Epoch 474/500
# 1/1 [==============================] - 0s 13ms/step - loss: 3.8166e-06
# Epoch 475/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.7383e-06
# Epoch 476/500
# 1/1 [==============================] - 0s 5ms/step - loss: 3.6614e-06
# Epoch 477/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.5863e-06
# Epoch 478/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.5127e-06
# Epoch 479/500
# 1/1 [==============================] - 0s 20ms/step - loss: 3.4405e-06
# Epoch 480/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3696e-06
# Epoch 481/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.3005e-06
# Epoch 482/500
# 1/1 [==============================] - 0s 5ms/step - loss: 3.2328e-06
# Epoch 483/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.1663e-06
# Epoch 484/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.1012e-06
# Epoch 485/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.0375e-06
# Epoch 486/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.9751e-06
# Epoch 487/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9140e-06
# Epoch 488/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8540e-06
# Epoch 489/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.7955e-06
# Epoch 490/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.7379e-06
# Epoch 491/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.6814e-06
# Epoch 492/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.6264e-06
# Epoch 493/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.5726e-06
# Epoch 494/500
# 1/1 [==============================] - 0s 14ms/step - loss: 2.5197e-06
# Epoch 495/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4680e-06
# Epoch 496/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4171e-06
# Epoch 497/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.3677e-06
# Epoch 498/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.3191e-06
# Epoch 499/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2714e-06
# Epoch 500/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2245e-06

# %%
print(model.predict([10.0]))
# Out:
# [[30.99565]]

# %%
import cv2
import numpy as np
from scipy import misc
i = misc.ascent()

# %%
import matplotlib.pyplot as plt
plt.grid(False)
plt.gray()
plt.axis('off')
plt.imshow(i)
plt.show()

# %%
i_transformed = np.copy(i)
size_x = i_transformed.shape[0]
size_y = i_transformed.shape[1]

# %%
print(size_x)
print(size_y)
# Out:
# 512
# 512

# %%
filter = [ [-1, -2, -1], [0, 0, 0], [1, 2, 1]]
weight  = 1

# %%
for x in range(1,size_x-1):
  for y in range(1,size_y-1):
      output_pixel = 0.0
      output_pixel = output_pixel + (i[x - 1, y-1] * filter[0][0])
      output_pixel = output_pixel + (i[x, y-1] * filter[0][1])
      output_pixel = output_pixel + (i[x + 1, y-1] * filter[0][2])
      output_pixel = output_pixel + (i[x-1, y] * filter[1][0])
      output_pixel = output_pixel + (i[x, y] * filter[1][1])
      output_pixel = output_pixel + (i[x+1, y] * filter[1][2])
      output_pixel = output_pixel + (i[x-1, y+1] * filter[2][0])
      output_pixel = output_pixel + (i[x, y+1] * filter[2][1])
      output_pixel = output_pixel + (i[x+1, y+1] * filter[2][2])
      output_pixel = output_pixel * weight
      if(output_pixel<0):
        output_pixel=0
      if(output_pixel>255):
        output_pixel=255
      i_transformed[x, y] = output_pixel

# %%
plt.gray()
plt.grid(False)
plt.imshow(i_transformed)
plt.show()

# %%
new_x = int(size_x/2)
new_y = int(size_y/2)
newImage = np.zeros((new_x, new_y))
for x in range(0, size_x, 2):
  for y in range(0, size_y, 2):
    pixels = []
    pixels.append(i_transformed[x, y])
    pixels.append(i_transformed[x+1, y])
    pixels.append(i_transformed[x, y+1])
    pixels.append(i_transformed[x+1, y+1])
    pixels.sort(reverse=True)
    newImage[int(x/2),int(y/2)] = pixels[0]
 
# Plot the image. Note the size of the axes -- now 256 pixels instead of 512
plt.gray()
plt.grid(False)
plt.imshow(newImage)
#plt.axis('off')
plt.show()

# %%
import tensorflow as tf
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images=training_images/255.0
test_images=test_images/255.0
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(training_images, training_labels, epochs=5)
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print ('Test loss: {}, Test accuracy: {}'.format(test_loss, test_accuracy*100))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6334 - accuracy: 0.7807
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3783 - accuracy: 0.8646
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3429 - accuracy: 0.8769
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3135 - accuracy: 0.8854
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2953 - accuracy: 0.8917
# 313/313 [==============================] - 1s 1ms/step - loss: 0.3487 - accuracy: 0.8736
# Test loss: 0.3487430214881897, Test accuracy: 87.36000061035156

# %%
import tensorflow as tf
print(tf.__version__)
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images=training_images.reshape(60000, 28, 28, 1)
training_images=training_images / 255.0
test_images = test_images.reshape(10000, 28, 28, 1)
test_images=test_images / 255.0
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(64, (3, 3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
model.fit(training_images, training_labels, epochs=5)
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print ('Test loss: {}, Test accuracy: {}'.format(test_loss, test_accuracy*100))
# Out:
# 2.4.1
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               204928
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 243,786
# Trainable params: 243,786
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 70s 37ms/step - loss: 0.6048 - accuracy: 0.7794
# Epoch 2/5
# 1875/1875 [==============================] - 69s 37ms/step - loss: 0.2974 - accuracy: 0.8900
# Epoch 3/5
# 1875/1875 [==============================] - 69s 37ms/step - loss: 0.2469 - accuracy: 0.9096
# Epoch 4/5
# 1875/1875 [==============================] - 68s 36ms/step - loss: 0.2036 - accuracy: 0.9239
# Epoch 5/5
# 1875/1875 [==============================] - 69s 37ms/step - loss: 0.1826 - accuracy: 0.9330
# 313/313 [==============================] - 4s 12ms/step - loss: 0.2594 - accuracy: 0.9059
# Test loss: 0.25938934087753296, Test accuracy: 90.59000015258789

# %%
print(test_labels[:100])
# Out:
# [9 2 1 1 6 1 4 6 5 7 4 5 7 3 4 1 2 4 8 0 2 5 7 9 1 4 6 0 9 3 8 8 3 3 8 0 7
#  5 7 9 6 1 3 7 6 7 2 1 2 2 4 4 5 8 2 2 8 4 8 0 7 7 8 5 1 1 2 3 9 8 7 0 2 6
#  2 3 1 2 8 4 1 8 5 9 5 0 3 2 0 6 5 3 6 7 1 8 0 1 4 2]

# %%
import matplotlib.pyplot as plt
f, axarr = plt.subplots(3,4)
FIRST_IMAGE=0
SECOND_IMAGE=23
THIRD_IMAGE=28
CONVOLUTION_NUMBER = 6
from tensorflow.keras import models
layer_outputs = [layer.output for layer in model.layers]
activation_model = tf.keras.models.Model(inputs = model.input, outputs = layer_outputs)
for x in range(0,4):
  f1 = activation_model.predict(test_images[FIRST_IMAGE].reshape(1, 28, 28, 1))[x]
  axarr[0,x].imshow(f1[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
  axarr[0,x].grid(False)
  f2 = activation_model.predict(test_images[SECOND_IMAGE].reshape(1, 28, 28, 1))[x]
  axarr[1,x].imshow(f2[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
  axarr[1,x].grid(False)
  f3 = activation_model.predict(test_images[THIRD_IMAGE].reshape(1, 28, 28, 1))[x]
  axarr[2,x].imshow(f3[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
  axarr[2,x].grid(False)

# %%
# !wget --no-check-certificate https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip  -O /tmp/horse-or-human.zip
# Out:
# --2021-03-07 12:05:45--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.119.128, 108.177.126.128, 108.177.127.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.119.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149574867 (143M) [application/zip]
# Saving to: ‘/tmp/horse-or-human.zip’
#
# /tmp/horse-or-human 100%[===================>] 142.65M  40.7MB/s    in 3.5s
#
# 2021-03-07 12:05:49 (40.7 MB/s) - ‘/tmp/horse-or-human.zip’ saved [149574867/149574867]

# %%
import os
import zipfile
 
local_zip = '/tmp/horse-or-human.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/horse-or-human')
zip_ref.close()

# %%
# Directory with our training horse pictures
train_horse_dir = os.path.join('/tmp/horse-or-human/horses')
 
# Directory with our training human pictures
train_human_dir = os.path.join('/tmp/horse-or-human/humans')

# %%
train_horse_names = os.listdir(train_horse_dir)
print(train_horse_names[:10])
train_human_names = os.listdir(train_human_dir)
print(train_human_names[:10])
# Out:
# ['horse40-3.png', 'horse48-1.png', 'horse27-1.png', 'horse26-0.png', 'horse34-9.png', 'horse37-5.png', 'horse46-1.png', 'horse16-6.png', 'horse01-3.png', 'horse13-0.png']
# ['human12-03.png', 'human13-12.png', 'human07-28.png', 'human17-00.png', 'human06-08.png', 'human09-20.png', 'human02-08.png', 'human08-05.png', 'human09-08.png', 'human09-14.png']

# %%
print('total training horse images:', len(os.listdir(train_horse_dir)))
print('total training human images:', len(os.listdir(train_human_dir)))
# Out:
# total training horse images: 500
# total training human images: 527

# %%
# %matplotlib inline
 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
 
# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4
 
# Index for iterating over images
pic_index = 0

# %%
# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)
 
pic_index += 8
next_horse_pix = [os.path.join(train_horse_dir, fname) 
                for fname in train_horse_names[pic_index-8:pic_index]]
next_human_pix = [os.path.join(train_human_dir, fname) 
                for fname in train_human_names[pic_index-8:pic_index]]
 
for i, img_path in enumerate(next_horse_pix+next_human_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)
 
  img = mpimg.imread(img_path)
  plt.imshow(img)
 
plt.show()

# %%
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 300x300 with 3 bytes color
    # This is the first convolution
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # The second convolution
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The third convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fourth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fifth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('horses') and 1 for the other ('humans')
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 298, 298, 16)      448
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 149, 149, 16)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 147, 147, 32)      4640
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 73, 73, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 71, 71, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 35, 35, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 33, 33, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 1,704,097
# Trainable params: 1,704,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop
 
model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(lr=0.001),
              metrics=['acc'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
 
# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255)
 
# Flow training images in batches of 128 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        '/tmp/horse-or-human/',  # This is the source directory for training images
        target_size=(300, 300),  # All images will be resized to 150x150
        batch_size=128,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')
# Out:
# Found 1027 images belonging to 2 classes.

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=8,  
      epochs=15,
      verbose=1)
# Out:
# Epoch 1/15
# 8/8 [==============================] - 68s 9s/step - loss: 0.8488 - acc: 0.4828
# Epoch 2/15
# 8/8 [==============================] - 74s 9s/step - loss: 0.6698 - acc: 0.6490
# Epoch 3/15
# 8/8 [==============================] - 65s 8s/step - loss: 1.0847 - acc: 0.7518
# Epoch 4/15
# 8/8 [==============================] - 66s 8s/step - loss: 0.6500 - acc: 0.8400
# Epoch 5/15
# 8/8 [==============================] - 67s 8s/step - loss: 0.1968 - acc: 0.9309
# Epoch 6/15
# 8/8 [==============================] - 66s 8s/step - loss: 0.2048 - acc: 0.9291
# Epoch 7/15
# 8/8 [==============================] - 66s 8s/step - loss: 0.3892 - acc: 0.8913
# Epoch 8/15
# 8/8 [==============================] - 72s 9s/step - loss: 0.2131 - acc: 0.9120
# Epoch 9/15
# 8/8 [==============================] - 66s 8s/step - loss: 0.7426 - acc: 0.7779
# Epoch 10/15
# 8/8 [==============================] - 67s 8s/step - loss: 0.1947 - acc: 0.9197
# Epoch 11/15
# 8/8 [==============================] - 66s 8s/step - loss: 0.1806 - acc: 0.9239
# Epoch 12/15
# 8/8 [==============================] - 67s 8s/step - loss: 0.0625 - acc: 0.9724
# Epoch 13/15
# 8/8 [==============================] - 67s 9s/step - loss: 0.0783 - acc: 0.9793
# Epoch 14/15
# 8/8 [==============================] - 66s 8s/step - loss: 0.5716 - acc: 0.8780
# Epoch 15/15
# 8/8 [==============================] - 67s 8s/step - loss: 0.0799 - acc: 0.9743

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
 
uploaded = files.upload()
 
for fn in uploaded.keys():
 
  # predicting images
  path = '/content/' + fn
  img = image.load_img(path, target_size=(300, 300))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
 
  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(classes[0])
  if classes[0]>0.5:
    print(fn + " is a human")
  else:
    print(fn + " is a horse")
# Out:
#      <input type="file" id="files-23ea2e8d-1509-4829-9ea9-2c83896cd400" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23ea2e8d-1509-4829-9ea9-2c83896cd400">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving chris.tiff to chris.tiff
# [1.]
# chris.tiff is a human

# %%
import os
import zipfile
import random
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from shutil import copyfile

# %%
# If the URL doesn't work, visit https://www.microsoft.com/en-us/download/confirmation.aspx?id=54765
# And right click on the 'Download Manually' link to get a new URL to the dataset 
# Note: This is a very large dataset and will take time to download
# !wget --no-check-certificate "https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip" -O "/tmp/cats-and-dogs.zip"
local_zip = '/tmp/cats-and-dogs.zip'
zip_ref   = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()
print(len(os.listdir('/tmp/PetImages/Cat/')))
print(len(os.listdir('/tmp/PetImages/Dog/'))) 
# Expected Output:
# 12501
# 12501
# Out:
# --2021-04-02 10:00:19--  https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip
# Resolving download.microsoft.com (download.microsoft.com)... 23.35.72.22, 2600:1407:a800:19e::e59, 2600:1407:a800:1ac::e59
# Connecting to download.microsoft.com (download.microsoft.com)|23.35.72.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 824894548 (787M) [application/octet-stream]
# Saving to: ‘/tmp/cats-and-dogs.zip’
#
# /tmp/cats-and-dogs. 100%[===================>] 786.68M   101MB/s    in 8.2s
#
# 2021-04-02 10:00:27 (95.8 MB/s) - ‘/tmp/cats-and-dogs.zip’ saved [824894548/824894548]
#
# 12501
# 12501

# %%
try:
    os.mkdir('/tmp/cats-v-dogs')
    os.mkdir('/tmp/cats-v-dogs/training')
    os.mkdir('/tmp/cats-v-dogs/testing')
    os.mkdir('/tmp/cats-v-dogs/training/cats')
    os.mkdir('/tmp/cats-v-dogs/training/dogs')
    os.mkdir('/tmp/cats-v-dogs/testing/cats')
    os.mkdir('/tmp/cats-v-dogs/testing/dogs')
except OSError:
    pass

def split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE):
    files = []
    for filename in os.listdir(SOURCE):
        file = SOURCE + filename
        if os.path.getsize(file) > 0:
            files.append(filename)
        else:
            print(filename + " is zero length, so ignoring.")
 
    training_length = int(len(files) * SPLIT_SIZE)
    testing_length = int(len(files) - training_length)
    shuffled_set = random.sample(files, len(files))
    training_set = shuffled_set[0:training_length]
    testing_set = shuffled_set[:testing_length]
 
    for filename in training_set:
        this_file = SOURCE + filename
        destination = TRAINING + filename
        copyfile(this_file, destination)
 
    for filename in testing_set:
        this_file = SOURCE + filename
        destination = TESTING + filename
        copyfile(this_file, destination)
 
 
CAT_SOURCE_DIR = "/tmp/PetImages/Cat/"
TRAINING_CATS_DIR = "/tmp/cats-v-dogs/training/cats/"
TESTING_CATS_DIR = "/tmp/cats-v-dogs/testing/cats/"
DOG_SOURCE_DIR = "/tmp/PetImages/Dog/"
TRAINING_DOGS_DIR = "/tmp/cats-v-dogs/training/dogs/"
TESTING_DOGS_DIR = "/tmp/cats-v-dogs/testing/dogs/"
 
split_size = .9
split_data(CAT_SOURCE_DIR, TRAINING_CATS_DIR, TESTING_CATS_DIR, split_size)
split_data(DOG_SOURCE_DIR, TRAINING_DOGS_DIR, TESTING_DOGS_DIR, split_size)
# Expected output
# 666.jpg is zero length, so ignoring
# 11702.jpg is zero length, so ignoring
# Out:
# 666.jpg is zero length, so ignoring.
# 11702.jpg is zero length, so ignoring.

# %%
print(len(os.listdir('/tmp/cats-v-dogs/training/cats/')))
print(len(os.listdir('/tmp/cats-v-dogs/training/dogs/')))
print(len(os.listdir('/tmp/cats-v-dogs/testing/cats/')))
print(len(os.listdir('/tmp/cats-v-dogs/testing/dogs/')))
# Expected output:
# 11250
# 11250
# 1250
# 1250
# Out:
# 11250
# 11250
# 1250
# 1250

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
]) 
model.compile(optimizer=RMSprop(lr=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
TRAINING_DIR = "/tmp/cats-v-dogs/training/"
train_datagen = ImageDataGenerator(rescale=1.0/255.)
train_generator = train_datagen.flow_from_directory(TRAINING_DIR,
                                                    batch_size=100,
                                                    class_mode='binary',
                                                    target_size=(150, 150))
 
VALIDATION_DIR = "/tmp/cats-v-dogs/testing/"
validation_datagen = ImageDataGenerator(rescale=1.0/255.)
validation_generator = validation_datagen.flow_from_directory(VALIDATION_DIR,
                                                              batch_size=100,
                                                              class_mode='binary',
                                                              target_size=(150, 150))
 
# Expected Output:
# Found 22498 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.
# Out:
# Found 22498 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.

# %%
# Note that this may take some time.
history = model.fit_generator(train_generator,
                              epochs=5,
                              verbose=1,
                              validation_data=validation_generator)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/15
#  49/225 [=====>........................] - ETA: 6:00 - loss: 1.3745 - accuracy: 0.5397
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32 bytes but only got 0. Skipping tag 270
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5 bytes but only got 0. Skipping tag 271
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 272
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 282
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 283
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 20 bytes but only got 0. Skipping tag 306
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 48 bytes but only got 0. Skipping tag 532
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# 225/225 [==============================] - 483s 2s/step - loss: 0.8907 - accuracy: 0.5915 - val_loss: 0.6018 - val_accuracy: 0.6788
# Epoch 2/15
# 171/225 [=====================>........] - ETA: 1:49 - loss: 0.5506 - accuracy: 0.7295

# %%
# %matplotlib inline
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']
 
epochs=range(len(acc)) # Get number of epochs
 
#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.figure()
 
#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")
plt.figure()

# %%
# Here's a codeblock just for fun. You should be able to upload an image here 
# and have it classified without crashing
import numpy as np
from google.colab import files
from keras.preprocessing import image
 
uploaded = files.upload()
 
for fn in uploaded.keys():
 
  # predicting images
  path = '/content/' + fn
  img = image.load_img(path, target_size=(150, 150))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
 
  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(classes[0])
  if classes[0]>0.5:
    print(fn + " is a dog")
  else:
    print(fn + " is a cat")
